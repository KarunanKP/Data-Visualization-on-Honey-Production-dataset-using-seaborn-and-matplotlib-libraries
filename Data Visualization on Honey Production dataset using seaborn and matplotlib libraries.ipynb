# %% [markdown]
# ## 1. Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# ## 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
df.shape            #---The dataset has 626 Rows and 8 Columns.
# Out:
# (626, 8)

# %%
df.info()           #---There are no null values in the Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()   #---From this we can conclude that there are no null values in the Dataset.
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
df.dtypes           #---From this we can conclude that there are no Garbage values in the Dataset.
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#        state         numcol  yieldpercol     totalprod        stocks  \
# count    626     626.000000   626.000000  6.260000e+02  6.260000e+02
# unique    44            NaN          NaN           NaN           NaN
# top       AL            NaN          NaN           NaN           NaN
# freq      15            NaN          NaN           NaN           NaN
# mean     NaN   60284.345048    62.009585  4.169086e+06  1.318859e+06
# std      NaN   91077.087231    19.458754  6.883847e+06  2.272964e+06
# min      NaN    2000.000000    19.000000  8.400000e+04  8.000000e+03
# 25%      NaN    9000.000000    48.000000  4.750000e+05  1.430000e+05
# 50%      NaN   26000.000000    60.000000  1.533000e+06  4.395000e+05
# 75%      NaN   63750.000000    74.000000  4.175250e+06  1.489500e+06
# max      NaN  510000.000000   136.000000  4.641000e+07  1.380000e+07
#
#         priceperlb     prodvalue         year
# count   626.000000  6.260000e+02   626.000000
# ...

# %%
df.duplicated().sum()    #---There is no Duplicates in the Dataset.
# Out:
# 0

# %% [markdown]
# ## 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
plt.pie(df['year'].value_counts(),labels=df.groupby(df['year'])['year'].count().index,autopct='%1.1f%%')
plt.title('Distribution of the data in each year');

# %% [markdown]
# ## 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
srt =sorted(df['priceperlb'].unique())
srt
# Out:
# [0.49,
#  0.52,
#  0.53,
#  0.54,
#  0.55,
#  0.56,
#  0.57,
#  0.58,
#  0.59,
#  0.6,
#  0.61,
#  0.62,
#  0.63,
#  0.64,
#  0.65,
#  0.66,
#  0.67,
#  0.68,
#  0.69,
#  0.7,
#  0.71,
#  0.72,
#  0.73,
#  0.74,
#  0.75,
#  0.76,
#  0.77,
#  0.79,
#  0.8,
#  0.81,
#  0.82,
#  0.83,
#  0.85,
#  0.86,
#  0.87,
#  0.89,
#  0.9,
#  0.91,
#  0.92,
#  0.93,
#  0.94,
#  0.95,
#  0.96,
#  0.97,
#  0.98,
#  0.99,
#  1.0,
#  1.01,
#  1.02,
#  1.03,
#  1.04,
#  1.05,
#  1.06,
#  1.08,
#  1.09,
#  1.1,
#  1.11,
#  1.12,
#  1.13,
#  1.14,
#  1.15,
#  1.16,
#  1.17,
#  1.18,
#  1.19,
#  1.2,
#  1.21,
#  1.22,
#  1.23,
#  1.24,
#  1.25,
#  1.26,
#  1.27,
#  1.28,
#  1.29,
#  1.3,
#  1.31,
#  1.32,
#  1.33,
#  1.34,
#  1.35,
#  1.36,
#  1.37,
#  1.38,
#  1.39,
#  1.4,
#  1.41,
#  1.42,
#  1.43,
#  1.44,
#  1.45,
#  1.46,
#  1.47,
#  1.48,
#  1.49,
#  1.5,
#  1.51,
#  1.52,
#  1.53,
#  1.54,
#  1.55,
#  1.56,
#  1.57,
#  1.58,
#  1.59,
#  1.6,
#  1.61,
#  1.62,
#  1.63,
#  1.64,
#  1.65,
#  1.66,
# ...

# %%
sns.displot(df['priceperlb'])
plt.title('Distribution of the variable "price per lb"')
plt.show()
# Out:
# C:\Users\karunan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Analysis:
# - The Distribution Positively Skewed as the right tail is longer.
# - The Distribution ranges between '0.49' to '4.15'.
# - The Mean and Median lies between '1.4' and '1.6'.
# - Most of the Values lies between '0.49' and '2.0'.
# ### Inference:
# - As the "price per lb" increases the count tends to decrease. Indicating that majority of the honeys are sold at a lower price range.
# - More no.of honeys are sold in a Price range '1.4' to '1.6'.

# %% [markdown]
# ## 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
df.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
sns.scatterplot(x= df['numcol'], y= df['prodvalue'],hue=df['prodvalue'], )
plt.title('Relationship between Numcol and prodvalue');

# %% [markdown]
# ### Inference:
# - The variables 'numcol' and 'prodvalue' has a positive relationship or positive correlation.
# - Majority of the data lies under 150000 'numcols' and their 'prodvalue' is respectively under 15 million
# - The Data is spreaded above 200000 'numcols' and only some of them seems to have a 'prodvalue' of above 50 million.
# - So, we cannot only considers the relationship between 'numcols' and 'prodvalue' as there are some other factors influencing 'prodvalue'.

# %% [markdown]
# ## 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(12,5))
sns.boxplot(x=df['year'],y = df['prodvalue'])
plt.title('Relationship between Year and Prodvalue')
plt.show()

# %% [markdown]
# ### Inference:
# - The IQRs seems to varies significantly, indicating wide spread in data.
# - There seems to be a noticable variation in 'prodvalue' across different 'year'.
# - There are noticable amount of outliers in every year, and the year from 2008 to 2012 has the major outlier.
# - The Data seems to be positively skewed, as the UWL is noticable longer.

# %% [markdown]
# ## 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
col = ['numcol','yieldpercol','totalprod','prodvalue','year']
col
# Out:
# ['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year']

# %%
sns.pairplot(df[col], kind='reg',corner=True);
# Out:
# C:\Users\karunan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Inference:
# - The 'totalprod' and 'prodvalue' seems to be positively correlated with 'numcol'.
# - which signifies that the increase in 'numcol' tends to increase the 'prodvalue' and 'totalprod'.
# - similarly 'totalprod' and 'prodvalue' are also positively correlated.
# - while considering the diagonal histograms 'numcol','totalprod','prodvalue' are positively skewed.
# - The yieldpercol seems to have a normal distribution.
# - The 'year' has no relationship with any of the variable.

# %% [markdown]
# ## 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
cols= ['numcol','yieldpercol','totalprod','stocks','priceperlb','prodvalue']

# %%
sns.heatmap(df[cols].corr(),annot= True, cmap='GnBu')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Inference:
# - From the Heatmap we can infer the relationship between two variables.
# - 'numcol' is positively correlated with 'totalprod' , 'prodvalue' , 'stocks'.
# - 'totalprod' is positively correlated with 'prodvalue' , 'stocks'.
# - 'stocks' is positively correlated with 'prodvalue'.
# - The above variable are Directly proportional to each other.
# - 'yieldpercol' has less positive relationship with other variables.
# - 'priceperlb' indicates a negatively correlated with every other variable, indicating a inversely proportional.
